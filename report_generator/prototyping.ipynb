# %%
#from utils.report_cleaner import excelcleaner
from report_generator.utils.report_cleaner.excelToPandasToJson import ConvertCleanSave
import utils
import pandas as pd

file_path1 = "./mocks/excel_reports/10-K-15.xlsx"
file_path2 = "./mocks/excel_reports/10-K-20.xlsx"

# %%
test = ConvertCleanSave(file_path1)
test1 = ConvertCleanSave(file_path2)
# Out:
# C:\Users\Tutrie\anaconda3\envs\CMSC435\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %%
df1 = list(test.pandas_dict.values())[0]
df2 = list(test1.pandas_dict.values())[0]

# %%
pd.concat([df1, df2], axis=1)
# Out:
#                                                      Nov. 28, 2015 - 12 Months Ended  \
# index
# Entity Registrant Name                              BASSETT FURNITURE INDUSTRIES INC
# Entity Central Index Key                                                       10329
# Trading Symbol                                                                  bset
# Current Fiscal Year End Date                                                 --11-28
# Entity Filer Category                                              Accelerated Filer
# Entity Current Reporting Status                                                  Yes
# Entity Voluntary Filers                                                           No
# Entity Well-known Seasoned Issuer                                                 No
# Entity Common Stock, Shares Outstanding (in sha...                               NaN
# Entity Public Float                                                              NaN
# Document Type                                                                   10-K
# Document Period End Date                                          Nov. 28,\n\t\t2015
# Document Fiscal Year Focus                                                      2015
# Document Fiscal Period Focus                                                      FY
# Amendment Flag                                                                 false
# Document Information [Line Items] - CATEGORY                                     NaN
# Document Annual Report                                                           NaN
# Document Transition Report                                                       NaN
# Entity File Number                                                               NaN
# Entity Incorporation, State or Country Code                                      NaN
# Entity Tax Identification Number                                                 NaN
# Entity Address, Address Line One                                                 NaN
# Entity Address, City or Town                                                     NaN
# Entity Address, State or Province                                                NaN
# Entity Address, Postal Zip Code                                                  NaN
# City Area Code                                                                   NaN
# Local Phone Number                                                               NaN
# Title of 12(b) Security                                                          NaN
# Security Exchange Name                                                           NaN
# Entity Interactive Data Current                                                  NaN
# Entity Small Business                                                            NaN
# Entity Emerging Growth Company                                                   NaN
# Entity Shell Company                                                             NaN
# Entity Common Stock, Shares Outstanding                                          NaN
#
#                                                     Jan. 08, 2016  \
# index
# Entity Registrant Name                                        NaN
# Entity Central Index Key                                      NaN
# Trading Symbol                                                NaN
# Current Fiscal Year End Date                                  NaN
# Entity Filer Category                                         NaN
# Entity Current Reporting Status                               NaN
# Entity Voluntary Filers                                       NaN
# Entity Well-known Seasoned Issuer                             NaN
# Entity Common Stock, Shares Outstanding (in sha...     10870858.0
# Entity Public Float                                           NaN
# Document Type                                                 NaN
# Document Period End Date                                      NaN
# Document Fiscal Year Focus                                    NaN
# Document Fiscal Period Focus                                  NaN
# Amendment Flag                                                NaN
# Document Information [Line Items] - CATEGORY                  NaN
# Document Annual Report                                        NaN
# Document Transition Report                                    NaN
# Entity File Number                                            NaN
# Entity Incorporation, State or Country Code                   NaN
# Entity Tax Identification Number                              NaN
# Entity Address, Address Line One                              NaN
# Entity Address, City or Town                                  NaN
# Entity Address, State or Province                             NaN
# Entity Address, Postal Zip Code                               NaN
# City Area Code                                                NaN
# Local Phone Number                                            NaN
# Title of 12(b) Security                                       NaN
# Security Exchange Name                                        NaN
# Entity Interactive Data Current                               NaN
# Entity Small Business                                         NaN
# Entity Emerging Growth Company                                NaN
# Entity Shell Company                                          NaN
# Entity Common Stock, Shares Outstanding                       NaN
#
#                                                     May. 30, 2015  \
# index
# Entity Registrant Name                                        NaN
# Entity Central Index Key                                      NaN
# Trading Symbol                                                NaN
# Current Fiscal Year End Date                                  NaN
# Entity Filer Category                                         NaN
# Entity Current Reporting Status                               NaN
# Entity Voluntary Filers                                       NaN
# Entity Well-known Seasoned Issuer                             NaN
# Entity Common Stock, Shares Outstanding (in sha...            NaN
# Entity Public Float                                   308300086.0
# Document Type                                                 NaN
# Document Period End Date                                      NaN
# Document Fiscal Year Focus                                    NaN
# Document Fiscal Period Focus                                  NaN
# Amendment Flag                                                NaN
# Document Information [Line Items] - CATEGORY                  NaN
# Document Annual Report                                        NaN
# Document Transition Report                                    NaN
# Entity File Number                                            NaN
# Entity Incorporation, State or Country Code                   NaN
# Entity Tax Identification Number                              NaN
# Entity Address, Address Line One                              NaN
# Entity Address, City or Town                                  NaN
# Entity Address, State or Province                             NaN
# Entity Address, Postal Zip Code                               NaN
# City Area Code                                                NaN
# Local Phone Number                                            NaN
# Title of 12(b) Security                                       NaN
# Security Exchange Name                                        NaN
# Entity Interactive Data Current                               NaN
# Entity Small Business                                         NaN
# Entity Emerging Growth Company                                NaN
# Entity Shell Company                                          NaN
# Entity Common Stock, Shares Outstanding                       NaN
#
#                                                      Nov. 28, 2020 - 12 Months Ended  \
# index
# Entity Registrant Name                              BASSETT FURNITURE INDUSTRIES INC
# Entity Central Index Key                                                  0000010329
# Trading Symbol                                                                  BSET
# Current Fiscal Year End Date                                                 --11-28
# Entity Filer Category                                              Accelerated Filer
# Entity Current Reporting Status                                                  Yes
# Entity Voluntary Filers                                                           No
# Entity Well-known Seasoned Issuer                                                 No
# Entity Common Stock, Shares Outstanding (in sha...                               NaN
# Entity Public Float                                                              NaN
# Document Type                                                                   10-K
# Document Period End Date                                          Nov. 28,\n\t\t2020
# Document Fiscal Year Focus                                                      2020
# Document Fiscal Period Focus                                                      FY
# Amendment Flag                                                                 false
# Document Information [Line Items] - CATEGORY                                     NaN
# Document Annual Report                                                          true
# Document Transition Report                                                     false
# Entity File Number                                                         000-00209
# Entity Incorporation, State or Country Code                                       VA
# Entity Tax Identification Number                                          54-0135270
# Entity Address, Address Line One                        3525 Fairystone Park Highway
# Entity Address, City or Town                                                 Bassett
# Entity Address, State or Province                                                 VA
# Entity Address, Postal Zip Code                                                24055
# City Area Code                                                                   276
# Local Phone Number                                                          629-6000
# Title of 12(b) Security                               Common Stock ($5.00 par value)
# Security Exchange Name                                                        NASDAQ
# Entity Interactive Data Current                                                  Yes
# Entity Small Business                                                          false
# Entity Emerging Growth Company                                                 false
# Entity Shell Company                                                           false
# Entity Common Stock, Shares Outstanding                                          NaN
#
#                                                     Jan. 15, 2021  \
# index
# Entity Registrant Name                                        NaN
# Entity Central Index Key                                      NaN
# Trading Symbol                                                NaN
# Current Fiscal Year End Date                                  NaN
# Entity Filer Category                                         NaN
# Entity Current Reporting Status                               NaN
# Entity Voluntary Filers                                       NaN
# Entity Well-known Seasoned Issuer                             NaN
# Entity Common Stock, Shares Outstanding (in sha...            NaN
# Entity Public Float                                           NaN
# Document Type                                                 NaN
# Document Period End Date                                      NaN
# Document Fiscal Year Focus                                    NaN
# Document Fiscal Period Focus                                  NaN
# Amendment Flag                                                NaN
# Document Information [Line Items] - CATEGORY                  NaN
# Document Annual Report                                        NaN
# Document Transition Report                                    NaN
# Entity File Number                                            NaN
# Entity Incorporation, State or Country Code                   NaN
# Entity Tax Identification Number                              NaN
# Entity Address, Address Line One                              NaN
# Entity Address, City or Town                                  NaN
# Entity Address, State or Province                             NaN
# Entity Address, Postal Zip Code                               NaN
# City Area Code                                                NaN
# Local Phone Number                                            NaN
# Title of 12(b) Security                                       NaN
# Security Exchange Name                                        NaN
# Entity Interactive Data Current                               NaN
# Entity Small Business                                         NaN
# Entity Emerging Growth Company                                NaN
# Entity Shell Company                                          NaN
# Entity Common Stock, Shares Outstanding                 9949008.0
#
#                                                     May 30, 2020
# index
# Entity Registrant Name                                       NaN
# Entity Central Index Key                                     NaN
# Trading Symbol                                               NaN
# Current Fiscal Year End Date                                 NaN
# Entity Filer Category                                        NaN
# Entity Current Reporting Status                              NaN
# Entity Voluntary Filers                                      NaN
# Entity Well-known Seasoned Issuer                            NaN
# Entity Common Stock, Shares Outstanding (in sha...           NaN
# Entity Public Float                                   68257836.0
# Document Type                                                NaN
# Document Period End Date                                     NaN
# Document Fiscal Year Focus                                   NaN
# Document Fiscal Period Focus                                 NaN
# Amendment Flag                                               NaN
# Document Information [Line Items] - CATEGORY                 NaN
# Document Annual Report                                       NaN
# Document Transition Report                                   NaN
# Entity File Number                                           NaN
# Entity Incorporation, State or Country Code                  NaN
# Entity Tax Identification Number                             NaN
# Entity Address, Address Line One                             NaN
# Entity Address, City or Town                                 NaN
# Entity Address, State or Province                            NaN
# Entity Address, Postal Zip Code                              NaN
# City Area Code                                               NaN
# Local Phone Number                                           NaN
# Title of 12(b) Security                                      NaN
# Security Exchange Name                                       NaN
# Entity Interactive Data Current                              NaN
# Entity Small Business                                        NaN
# Entity Emerging Growth Company                               NaN
# Entity Shell Company                                         NaN
# Entity Common Stock, Shares Outstanding                      NaN
